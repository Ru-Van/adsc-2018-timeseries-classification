# %% [markdown]
# # Setup

# %%
# %load_ext autotime
# %matplotlib inline

# %%
import pickle
# Out:
# time: 715 µs

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
# Out:
# time: 227 ms

# %% [markdown]
# # Load the Data

# %%
with open("data.pickle", "rb") as f:
    data = pickle.load(f)
# Out:
# time: 1.08 s

# %%
X = data["X"]
y = data["y"]
names = data["names"]
# Out:
# time: 2.16 ms

# %% [markdown]
# # Visualize the data

# %%
def show(i):
    print(f"Observation #{i} (Id {names[i]}):")
    pd.DataFrame(X[i].T).plot(subplots=True, figsize=(10, 60))
    plt.show()
# Out:
# time: 120 ms

# %%
def show_single(i, j):
    print(f"Observation #{i} (Id {names[i]}) - series #{j}:")
    plt.figure(figsize=(12, 2))
    plt.plot(X[i, j])
    plt.show()
# Out:
# time: 173 ms

# %% [markdown]
# ## Time series of healthy factories

# %%
for i in np.random.choice(np.where(y == 0)[0], size=3, replace=False):
    show(i)
# Out:
# Observation #244 (Id 491):
# Observation #42 (Id 78):
# Observation #162 (Id 327):
# time: 21.4 s

# %% [markdown]
# ## Time series of heavy smoker factories

# %% [markdown]
# ### Peaks

# %%
for i, j in [(59, 4), (59, 31), (249, 34), (237, 20), (245, 7)]:
    show_single(i, j)
# Out:
# Observation #59 (Id 111) - series #4:
# Observation #59 (Id 111) - series #31:
# Observation #249 (Id 499) - series #34:
# Observation #237 (Id 474) - series #20:
# Observation #245 (Id 492) - series #7:
# time: 700 ms

# %% [markdown]
# ### Noises

# %%
for i, j in [(61, 45), (61, 4), (188, 46), (113, 45), (129, 2)]:
    show_single(i, j)
# Out:
# Observation #61 (Id 115) - series #45:
# Observation #61 (Id 115) - series #4:
# Observation #188 (Id 381) - series #46:
# Observation #113 (Id 212) - series #45:
# Observation #129 (Id 257) - series #2:
# time: 590 ms

# %% [markdown]
# ### Constants

# %%
for i, j in [(168, 52), (101, 38), (168, 52), (79, 16)]:
    show_single(i, j)
# Out:
# Observation #168 (Id 335) - series #52:
# Observation #101 (Id 192) - series #38:
# Observation #168 (Id 335) - series #52:
# Observation #79 (Id 149) - series #16:
# time: 525 ms

# %% [markdown]
# ### "Special cases"

# %%
for i, j in [(201, 40), (201, 54), (103, 29)]:
    show_single(i, j)
# Out:
# Observation #201 (Id 400) - series #40:
# Observation #201 (Id 400) - series #54:
# Observation #103 (Id 194) - series #29:
# time: 308 ms
